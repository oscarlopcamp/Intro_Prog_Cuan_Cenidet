# %% [markdown]
# <center>
#
# # Introduccion a Programación Cuántica – CENIDET
#
# ## 🧠Multiples Qubits 🧠
# Autor: **Oscar Alejandro López Campero**
# Maestría en Ciencias de la Computación – Línea de Ingeniería de Software
# Agosto 2025
#
# ---
#
# </center>

# %% [markdown]
# ## 📚 Contenido del Módulo: Sistemas de Múltiples Qubits y Compuertas Compuestas
#
# En este módulo el estudiante aprenderá a construir, visualizar y analizar circuitos cuánticos que involucran **más de un qubit**, y a utilizar **secuencias de compuertas** para generar estados más complejos, como las **superposiciones múltiples** y los **estados entrelazados**.
#
# Se sentarán las bases necesarias para entender fenómenos cuánticos fundamentales y preparar el camino hacia la medición, la interferencia y los algoritmos cuánticos.
#
# ---
#
# ## 🧾 Temario
#
# 1️⃣ **Creación de sistemas con múltiples qubits**
# 2️⃣ **Aplicación de compuertas individuales en sistemas de 2 qubits**
# 3️⃣ **Aplicación de compuertas individuales en ambos qubits**
# 4️⃣ **Superposición en sistemas de 2 qubits**
# 5️⃣ **Entrelazamiento: creación del estado de Bell**
# 6️⃣ **Aplicar múltiples compuertas en un mismo qubit**
# 7️⃣ **Generación de los cuatro estados de Bell**
# 8️⃣ **Comparación visual de los estados de Bell**
#
# ---

# %% [markdown]
# ---
#
# ## 🧩 Sección 1 – Creación de sistemas con múltiples qubits
#
# Hasta ahora hemos trabajado con circuitos de **un solo qubit**, donde el estado era una combinación de `|0⟩` y `|1⟩`.
#
# Ahora construiremos circuitos con **dos qubits**, lo cual da lugar a **cuatro posibles estados base**:
#
# - `|00⟩`
# - `|01⟩`
# - `|10⟩`
# - `|11⟩`
#
# Estos forman la **base computacional** para sistemas de 2 qubits.
# Cualquier combinación lineal de estos estados es válida para describir un sistema cuántico de dos qubits.
#
# ---
#
# En Qiskit, se crea un sistema de 2 qubits así:

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex
from IPython.display import display

# Crear circuito con 2 qubits
qc = QuantumCircuit(2)
psi = Statevector(qc)

# Mostrar circuito vacío
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema |00⟩:")
display(array_to_latex(psi.data))

# Mostrar en notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))
# Out:
# 🧪 Estado vectorial del sistema |00⟩:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$ |00\rangle$$

# %% [markdown]
# ---
#
# ### ✅ Explicación del resultado
#
# - El sistema comienza en el estado `|00⟩`, lo cual significa que **ambos qubits están en `|0⟩`**.
# - El vector de estado tiene **cuatro componentes**, y solo la correspondiente a `|00⟩` tiene valor `1`; las demás son `0`.
# - El orden en Qiskit sigue la convención **little-endian**, lo que significa que el qubit **de mayor índice (qubit 1)** es el más significativo.
#
# Esto es importante para interpretar correctamente las posiciones en el vector de estado:
#
# $$
# [|00⟩,\ |01⟩,\ |10⟩,\ |11⟩]
# $$
#
# ---
#
# 📌 En la siguiente sección aplicaremos compuertas a uno de los qubits para cambiar el estado, y observaremos cómo se modifica el sistema completo.

# %% [markdown]
# ---
#
# # ⚙️ Sección 2 – Aplicación de compuertas individuales en sistemas de 2 qubits
#
# Ahora que hemos creado un sistema con dos qubits en estado `|00⟩`, aplicaremos una **compuerta X al qubit 1**, para transformar el estado a `|01⟩`.
#
# Recordemos que:
# - `qubit 0` es el de **abajo** (menos significativo)
# - `qubit 1` es el de **arriba** (más significativo)
#
# Por tanto, aplicar `X(1)` transforma:
#
# $$
# |00⟩ \quad \longrightarrow \quad |01⟩
# $$
#
# Vamos a observar cómo se modifica el circuito, el vector de estado y su notación ket.
#
# También utilizaremos la función `plot_state_qsphere()` para visualizar el estado resultante en una **QSphere**, una herramienta gráfica que representa el **estado completo del sistema cuántico**, incluyendo las **probabilidades y fases cuánticas** de cada uno de los estados base.

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito y aplicar compuerta X al qubit 1
qc = QuantumCircuit(2)
qc.x(1)
psi = Statevector(qc)

# Mostrar circuito con compuerta X
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema:")
display(array_to_latex(psi.data))

# Mostrar en notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 Visualización en QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Estado vectorial del sistema:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 1 & 0  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$ |10\rangle$$
# 🧿 Visualización en QSphere:

# %% [markdown]
# ### 🧿 ¿Qué estamos viendo en la QSphere?
#
# La **QSphere** es una herramienta gráfica que nos permite observar el estado cuántico completo del sistema, mostrando:
#
# - Los **estados base** posibles (como `|00⟩`, `|01⟩`, `|10⟩`, `|11⟩`)
# - Las **probabilidades** de cada uno (tamaño del punto)
# - Las **fases cuánticas** relativas (color del punto)
#
# En esta visualización:
#
# - El punto correspondiente a `|11⟩` es el único que aparece grande, lo que indica que el sistema está **completamente en ese estado**.
# - Los demás puntos (`|00⟩`, `|01⟩`, `|10⟩`) tienen **amplitud cero**, por lo que no aparecen visibles.
# - El **color del punto** indica la **fase cuántica** del estado. En este caso, al no haber superposición, no hay interferencia ni fases relativas importantes.
#
# 📌 La QSphere es especialmente útil para representar **estados con múltiples componentes y fases complejas**, como cuando hay **superposición o entrelazamiento**. Aquí, como solo hay un estado (`|11⟩`), se ve un solo punto grande y bien definido.

# %% [markdown]
# ---
#
# ### ✅ Explicación del resultado
#
# Al aplicar la compuerta **X al qubit 1**, el estado del sistema cambia de:
#
# $$
# |00⟩ \quad \longrightarrow \quad |01⟩
# $$
#
# Esto significa que ahora:
# - El **qubit 1 (más significativo)** está en `|1⟩`
# - El **qubit 0 (menos significativo)** permanece en `|0⟩`
#
# Por tanto, el sistema está en el estado `|01⟩`.
#
# 📌 En el vector de estado, la única amplitud distinta de cero está en la **segunda posición**, que representa `|01⟩` según el orden de Qiskit:
#
# $$
# [|00⟩,\ |01⟩,\ |10⟩,\ |11⟩]
# $$

# %% [markdown]
# ---
#
# # 📌 Aplicar una compuerta X al qubit 0
#
# Ahora aplicaremos la **compuerta X al qubit 0**, el menos significativo. Esto transforma el estado de `|00⟩` a `|10⟩`.

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito y aplicar compuerta X al qubit 0
qc = QuantumCircuit(2)
qc.x(0)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema:")
display(array_to_latex(psi.data))

# Mostrar en notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 Visualización en QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Estado vectorial del sistema:
# $$
#
# \begin{bmatrix}
# 0 & 1 & 0 & 0  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$ |01\rangle$$
# 🧿 Visualización en QSphere:

# %% [markdown]
# ### ✅ Explicación del resultado
#
# Al aplicar la compuerta **X al qubit 0**, el estado del sistema cambia de:
#
# $$
# |00⟩ \quad \longrightarrow \quad |10⟩
# $$
#
# Esto significa que ahora:
# - El **qubit 1 (más significativo)** permanece en `|0⟩`
# - El **qubit 0 (menos significativo)** está en `|1⟩`
#
# Por tanto, el sistema está en el estado `|10⟩`.
#
# 📌 En el vector de estado, la única amplitud distinta de cero está en la **tercera posición**, que representa `|10⟩` según el orden de Qiskit:
#
# $$
# [|00⟩,\ |01⟩,\ |10⟩,\ |11⟩]
# $$

# %% [markdown]
# ---
#
# ## ⚙️ Sección 3 – Aplicación de compuertas individuales en ambos qubits
#
# Hasta ahora hemos aplicado compuertas individuales a **un solo qubit a la vez**.
# En esta sección aplicaremos **una compuerta a cada qubit** dentro del mismo circuito.
#
# Como ejemplo, aplicaremos la compuerta **X al qubit 0** y la compuerta **X al qubit 1**, lo cual transformará el estado inicial `|00⟩` en `|11⟩`.
#
# Esto nos permitirá observar cómo se comporta el sistema cuando **ambos qubits cambian simultáneamente**.
#
# ---

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito y aplicar compuertas X a ambos qubits
qc = QuantumCircuit(2)
qc.x(0)
qc.x(1)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema:")
display(array_to_latex(psi.data))

# Mostrar en notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 Visualización en QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Estado vectorial del sistema:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$ |11\rangle$$
# 🧿 Visualización en QSphere:

# %% [markdown]
# ### ✅ Explicación del resultado
#
# Al aplicar la compuerta **X al qubit 0 y al qubit 1**, el estado del sistema cambia de:
#
# $$
# |00⟩ \quad \longrightarrow \quad |11⟩
# $$
#
# Esto significa que ahora:
# - El **qubit 1 (más significativo)** está en `|1⟩`
# - El **qubit 0 (menos significativo)** también está en `|1⟩`
#
# Por tanto, el sistema está en el estado `|11⟩`.
#
# 📌 En el vector de estado, la única amplitud distinta de cero está en la **cuarta posición**, que representa `|11⟩` según el orden de Qiskit:
#
# $$
# [|00⟩,\ |01⟩,\ |10⟩,\ |11⟩]
# $$

# %% [markdown]
# ---
#
# ## ⚙️ Sección 4 – Superposición en sistemas de 2 qubits
#
# Hasta ahora hemos trabajado con qubits en estados clásicos (`|0⟩`, `|1⟩`).
# En esta sección vamos a introducir el concepto de **superposición**, aplicando una **compuerta Hadamard** al **qubit 0** mientras que el qubit 1 permanece en `|0⟩`.
#
# Esto genera un estado donde el sistema cuántico está simultáneamente en `|00⟩` y `|10⟩`.
#
# Utilizaremos la **QSphere** para visualizar cómo se distribuyen las amplitudes y las fases cuánticas en un sistema de 2 qubits en superposición.
#
# ---

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito y aplicar Hadamard al qubit 0
qc = QuantumCircuit(2)
qc.h(0)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema:")
display(array_to_latex(psi.data))

# Mostrar notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 Visualización en QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Estado vectorial del sistema:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |01\rangle$$
# 🧿 Visualización en QSphere:

# %% [markdown]
# ### 🧠 Interpretación de la QSphere
#
# En esta visualización podemos ver:
#
# - Dos puntos grandes: `|00⟩` y `|10⟩`, lo que indica que el sistema está en superposición entre esos dos estados
# - Ambos tienen **amplitud 1/√2** y la **misma fase** (por eso el mismo color)
# - Los estados `|01⟩` y `|11⟩` no aparecen (amplitud 0)
#
# Esto representa el estado:
#
# $$
# |\psi⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |10⟩)
# $$
#
# 📌 Es decir: el **qubit 0** está en superposición, y el **qubit 1** sigue en `|0⟩`.
#
# ---

# %% [markdown]
# ---
#
# ## ⚙️ Sección 5 – Entrelazamiento: creación del estado de Bell
#
# Ahora aplicaremos una compuerta **CNOT** al sistema cuántico que generamos previamente.
# Este sistema estaba en superposición: `(|00⟩ + |10⟩)/√2`, es decir, el **qubit 0** en superposición y el **qubit 1** en `|0⟩`.
#
# La **CNOT** aplicará una compuerta X al qubit 1 **solo si el qubit 0 está en `|1⟩`**.
#
# ---
#
# ### 🔗 ¿Qué significa que estén entrelazados?
#
# Este estado es **entrelazado**, lo que significa que los qubits están conectados:
#
# - Si mides el qubit 0 y da `0`, el qubit 1 también será `0`
# - Si mides el qubit 0 y da `1`, el qubit 1 también será `1`
#
# Aunque no los mires al mismo tiempo, **los resultados siempre estarán correlacionados**.
#
# Este tipo de conexión cuántica es lo que hace al entrelazamiento tan especial y útil en la computación cuántica.
#
# ---
#
# En Qiskit, esta compuerta se codifica como:
#
# ```python
# qc.cx(control, target)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito: Hadamard en qubit 0, luego CNOT (0 controla a 1)
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Estado vectorial del sistema:")
display(array_to_latex(psi.data))

# Mostrar notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 Visualización en QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Estado vectorial del sistema:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$
# 🧿 Visualización en QSphere:

# %% [markdown]
# ### 🧠 ¿Qué está pasando en este circuito?
#
# Vamos a explicar paso a paso, en palabras simples, qué ocurre en este circuito con una compuerta Hadamard y una CNOT:
#
# ---
#
# #### 1. Estado inicial
#
# Ambos qubits empiezan en `|0⟩`, por lo tanto el sistema está en:
# $$
# |00⟩
# $$
#
# ---
#
# #### 2. Aplicamos Hadamard al qubit 0
#
# Esto pone al **qubit 0** en **superposición**: está a la vez en `|0⟩` y `|1⟩`.
# El qubit 1 sigue en `|0⟩`.
#
# El nuevo estado del sistema es:
#
# $$
# |\psi⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |10⟩)
# $$
#
# Esto significa que hay:
# - 50% de probabilidad de que estén en `|00⟩`
# - 50% de probabilidad de que estén en `|10⟩`
#
# ---
#
# #### 3. Aplicamos la compuerta CNOT
#
# La **CNOT** funciona así:
# - Si el **qubit 0 (control)** está en `0`, no hace nada
# - Si está en `1`, aplica una compuerta **X** al **qubit 1 (objetivo)**
#
# Entonces:
# - `|00⟩` se queda igual
# - `|10⟩` se transforma en `|11⟩`
#
# El nuevo estado es:
#
# $$
# |\Phi^+⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |11⟩)
# $$
#
#
# ---

# %% [markdown]
# ### 🔗 Interpretación del estado de Bell
#
# El resultado de este circuito es un **estado entrelazado**:
#
# $$
# |\Phi^+⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |11⟩)
# $$
#
# Esto significa que:
#
# - Si medimos el sistema y el **qubit 0 da `0`**, el **qubit 1 también será `0`**
# - Si el **qubit 0 da `1`**, el **qubit 1 también será `1`**
# - ¡Están perfectamente correlacionados! 🔗
#
# En la **QSphere** se observa:
#
# - Dos puntos grandes: `|00⟩` y `|11⟩`
# - Ambos tienen amplitud 1/√2
# - El **color diferente** indica que tienen una **fase relativa** entre sí (aunque en este caso puede ser la misma)
#
# 📌 Este tipo de estados son la base para muchas aplicaciones de la computación y criptografía cuántica.
#
# ---

# %% [markdown]
# ---
#
# ## ⚙️ Sección 6 – Aplicar múltiples compuertas en un mismo qubit
#
# Hasta ahora solo hemos aplicado **una compuerta por qubit**.
# En esta sección aprenderemos que es posible aplicar **varias compuertas en el mismo qubit, una tras otra**.
#
# Esto es muy común en circuitos cuánticos, y permite **modificar gradualmente el estado de un qubit**.
#
# Veremos dos casos:
#
# - Aplicar `H` seguido de `X` al qubit 0
# - Aplicar `X` seguido de `H` al mismo qubit
#
# Veremos que **el orden importa** y el estado final cambia dependiendo del orden.
#
# ---

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Caso 1: aplicar Hadamard luego X al qubit 0
qc = QuantumCircuit(1)
qc.h(0)
qc.x(0)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))

# Mostrar notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 QSphere del estado:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# 🧿 QSphere del estado:

# %% [markdown]
# ### ✨ Caso 1 – Aplicar `H` seguido de `X` al qubit 0
#
# Primero aplicamos **Hadamard**, que pone al qubit 0 en superposición:
#
# $$
# |0⟩ \longrightarrow \frac{1}{\sqrt{2}}(|0⟩ + |1⟩)
# $$
#
# Después aplicamos la compuerta **X**, que **intercambia `|0⟩` por `|1⟩` y viceversa**.
#
# El efecto total es:
#
# $$
# \frac{1}{\sqrt{2}}(|0⟩ + |1⟩) \longrightarrow \frac{1}{\sqrt{2}}(|1⟩ + |0⟩) = \frac{1}{\sqrt{2}}(|0⟩ + |1⟩)
# $$
#
# En este caso, **el estado final es el mismo**, pero eso **no siempre ocurre**.
# Veamos qué pasa si invertimos el orden.
#
# ---

# %%
# Caso 2: aplicar X luego Hadamard al qubit 0
qc = QuantumCircuit(1)
qc.x(0)
qc.h(0)
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))

# Mostrar notación ket
print("🧪 Estado en notación ket:")
display(psi.draw('latex'))

# Mostrar QSphere
print("🧿 QSphere del estado:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Estado en notación ket:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$
# 🧿 QSphere del estado:

# %% [markdown]
# ### 🔁 Caso 2 – Aplicar `X` seguido de `H` al qubit 0
#
# Ahora primero aplicamos la compuerta **X**, que cambia el estado de `|0⟩` a `|1⟩`:
#
# $$
# |0⟩ \longrightarrow |1⟩
# $$
#
# Luego aplicamos la compuerta **Hadamard** al qubit 0, y transforma:
#
# $$
# |1⟩ \longrightarrow \frac{1}{\sqrt{2}}(|0⟩ - |1⟩)
# $$
#
# Este estado final **no es el mismo que en el caso anterior**, ya que ahora hay una **fase negativa**:
#
# $$
# |\psi⟩ = \frac{1}{\sqrt{2}}(|0⟩ - |1⟩)
# $$
#
# 📌 Esto demuestra que **el orden de las compuertas importa** y afecta al resultado final.
#
# ---

# %% [markdown]
# ---
#
# ## ⚙️ Sección 7 – Generación de los cuatro estados de Bell
#
# Los **estados de Bell** son ejemplos fundamentales de **entrelazamiento cuántico**.
# Cada uno representa un sistema de dos qubits **perfectamente correlacionados**, con distintas combinaciones de fases y amplitudes.
#
# Los 4 estados de Bell son:
#
# - $|\Phi^+⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |11⟩)$
# - $|\Phi^-⟩ = \frac{1}{\sqrt{2}}(|00⟩ - |11⟩)$
# - $|\Psi^+⟩ = \frac{1}{\sqrt{2}}(|01⟩ + |10⟩)$
# - $|\Psi^-⟩ = \frac{1}{\sqrt{2}}(|01⟩ - |10⟩)$
#
# En esta sección construiremos **cada uno paso a paso**, usando compuertas simples y visualizando su resultado.
#
# ---

# %% [markdown]
# ---
#
# ### 🔷 Estado de Bell 1: $|\Phi^+⟩ = \frac{1}{\sqrt{2}}(|00⟩ + |11⟩)$
#
# Este es el estado de Bell más común.
# Se genera aplicando una **Hadamard** al qubit 0 para crear superposición, y luego una compuerta **CNOT** para copiar esa superposición al qubit 1 y así entrelazarlos.
#
# Compuertas usadas:
# - `H(0)`: pone el qubit 0 en superposición
# - `CNOT(0, 1)`: entrelaza los qubits
#
# ---

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Circuito para el estado |Φ⁺⟩
qc = QuantumCircuit(2)
qc.h(0)       # Hadamard en qubit 0
qc.cx(0, 1)   # CNOT: control=0, target=1

# Obtener el estado
psi = Statevector(qc)

# Visualización
display(qc.draw('mpl'))
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))
print("🧪 Notación ket:")
display(psi.draw('latex'))
print("🧿 QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Notación ket:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$
# 🧿 QSphere:

# %% [markdown]
# ---
#
# ### 🔷 Estado de Bell 2: $|\Phi^-⟩ = \frac{1}{\sqrt{2}}(|00⟩ - |11⟩)$
#
# Este estado es similar a $|\Phi^+⟩$, pero incluye una **fase negativa** en el término $|11⟩$.
#
# Para generarlo, usamos:
#
# - `H(0)`: crea la superposición
# - `Z(0)`: agrega una fase negativa al estado $|1⟩$
# - `CNOT(0, 1)`: entrelaza los qubits
#
# 📌 **Compuerta nueva: `Z`**
# La compuerta Z **no cambia la probabilidad**, pero **agrega una fase negativa a $|1⟩$**.
# Esto no se nota en mediciones directas, pero **sí cambia el estado cuántico**.
#
# ---

# %%
# Circuito para el estado |Φ⁻⟩
qc = QuantumCircuit(2)
qc.h(0)       # Hadamard en qubit 0
qc.z(0)       # Fase negativa a |1⟩
qc.cx(0, 1)   # Entrelazamiento con CNOT

# Obtener el estado
psi = Statevector(qc)

# Visualización
display(qc.draw('mpl'))
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))
print("🧪 Notación ket:")
display(psi.draw('latex'))
print("🧿 QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Notación ket:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2}}{2} |11\rangle$$
# 🧿 QSphere:

# %% [markdown]
# ### 🧠 Paso a paso – Cómo se forma $|\Phi^-⟩$
#
# 1. **Estado inicial:**
#    $$|00⟩$$
#
# 2. **Hadamard en qubit 0:**
#    El qubit 0 entra en superposición:
#    $$
#    |0⟩ \longrightarrow \frac{1}{\sqrt{2}}(|0⟩ + |1⟩)
#    $$
#
#    Como el qubit 1 sigue en $|0⟩$, el sistema ahora está en:
#    $$
#    \frac{1}{\sqrt{2}}(|00⟩ + |10⟩)
#    $$
#
# 3. **Z en qubit 0:**
#    Agrega una **fase negativa** a la parte $|1⟩$ del qubit 0:
#    $$
#    \frac{1}{\sqrt{2}}(|00⟩ + |10⟩) \longrightarrow \frac{1}{\sqrt{2}}(|00⟩ - |10⟩)
#    $$
#
# 4. **CNOT:**
#    Si qubit 0 = `1`, cambia qubit 1. Entonces:
#    - $|00⟩$ se queda igual
#    - $|10⟩$ se convierte en $|11⟩$
#
#    Resultado:
#    $$
#    |\Phi^-⟩ = \frac{1}{\sqrt{2}}(|00⟩ - |11⟩)
#    $$
#
# ---
#
# 📌 En la **QSphere**, se observan dos puntos: $|00⟩$ y $|11⟩$ con **colores opuestos**, indicando la diferencia de fase.
#
# ---

# %% [markdown]
# ---
#
# ### 🔷 Estado de Bell 3: $|\Psi^+⟩ = \frac{1}{\sqrt{2}}(|01⟩ + |10⟩)$
#
# Este estado representa una **superposición entre dos configuraciones opuestas**:
# - qubit 0 = `0` y qubit 1 = `1`
# - qubit 0 = `1` y qubit 1 = `0`
#
# Es un estado **entrelazado**, donde si medimos uno de los qubits, el otro estará siempre en el valor contrario.
#
# Para generarlo, usamos:
#
# - `X(1)`: cambia el qubit 1 de `|0⟩` a `|1⟩`
# - `H(0)`: pone el qubit 0 en superposición
# - `CNOT(0, 1)`: entrelaza los qubits
#
# 📌 **Compuerta nueva: `X(1)`**
# La compuerta X invierte el estado del qubit:
# - `|0⟩` → `|1⟩`
# - `|1⟩` → `|0⟩`
#
# ---

# %%
# Circuito para el estado |Ψ⁺⟩
qc = QuantumCircuit(2)
qc.x(1)       # 1. Invertir qubit 1: |00⟩ → |01⟩
qc.h(0)       # 2. Superposición en qubit 0
qc.cx(0, 1)   # 3. Entrelazamiento con CNOT

# Obtener el estado
psi = Statevector(qc)

# Visualización
display(qc.draw('mpl'))
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))
print("🧪 Notación ket:")
display(psi.draw('latex'))
print("🧿 QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0  \\
#  \end{bmatrix}
# $$
# 🧪 Notación ket:
# $$\frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangle$$
# 🧿 QSphere:

# %% [markdown]
# ### 🧠 Paso a paso – Cómo se forma $|\Psi^+⟩$
#
# 1. **Estado inicial:**
#    $$
#    |00⟩
#    $$
#
# 2. **Aplicamos `X(1)`**:
#    Esto cambia el qubit 1 de $|0⟩$ a $|1⟩$:
#    $$
#    |00⟩ \longrightarrow |01⟩
#    $$
#
# 3. **Aplicamos `H(0)`**:
#    Esto pone el qubit 0 en superposición:
#    $$
#    |0⟩ \longrightarrow \frac{1}{\sqrt{2}}(|0⟩ + |1⟩)
#    $$
#
#    Entonces:
#    $$
#    \frac{1}{\sqrt{2}}(|0⟩ + |1⟩) \otimes |1⟩ = \frac{1}{\sqrt{2}}(|01⟩ + |11⟩)
#    $$
#
# 4. **Aplicamos `CNOT(0, 1)`**:
#    Esta compuerta actúa solo si qubit 0 es `1`:
#    - $|01⟩$ → se queda igual
#    - $|11⟩$ → qubit 1 cambia: $|11⟩ \rightarrow |10⟩$
#
#    Resultado final:
#    $$
#    |\Psi^+⟩ = \frac{1}{\sqrt{2}}(|01⟩ + |10⟩)
#    $$
#
# ---
#
# 📌 En la QSphere, se verán dos puntos grandes: $|01⟩$ y $|10⟩$, con el **mismo color**, indicando que tienen la **misma fase**.
#
# ---

# %% [markdown]
# ---
#
# ## ⚙️ Sección 7.4 – Estado de Bell 4: $|\Psi^+⟩ = \frac{1}{\sqrt{2}}(|01⟩ - |10⟩)$
#
# Este estado de Bell representa una **superposición entre los estados** \( |00⟩ \) **y** \( |11⟩ \), con una **fase negativa** en el segundo término:
#
# $$
# |\Phi^-⟩ = \frac{1}{\sqrt{2}}(|00⟩ - |11⟩)
# $$
#
# Para construir este estado en Qiskit, seguimos estos pasos:
#
# - Aplicamos una compuerta **Hadamard al qubit 0** para generar una superposición.
# - Aplicamos una compuerta **CNOT**, con el qubit 0 como control y el qubit 1 como objetivo → se crea entrelazamiento.
# - Finalmente, aplicamos una compuerta **Z al qubit 0**, que invierte la fase del término \( |11⟩ \), introduciendo el signo negativo.
#
# Este proceso nos lleva al estado final:
#
# $$
# |\Phi^-⟩
# $$
#
# Uno de los cuatro **estados de Bell**, fundamentales en protocolos como la **teleportación cuántica**, **criptografía cuántica** y **pruebas de Bell**.
#
# ---

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex, plot_state_qsphere
from IPython.display import display

# Crear circuito cuántico con 2 qubits
qc = QuantumCircuit(2)

# Paso 1: Hadamard en qubit 0 → superposición
qc.h(0)

# Paso 2: CNOT entre qubit 0 (control) y qubit 1 (target) → entrelazamiento
qc.cx(0, 1)

# Paso 3: Z en qubit 0 → cambia la fase del término |11⟩
qc.z(0)

# Obtener estado
psi = Statevector(qc)

# Mostrar circuito
display(qc.draw('mpl'))

# Mostrar vector de estado
print("🧪 Vector de estado:")
display(array_to_latex(psi.data))

# Mostrar notación ket
print("🧪 Notación ket:")
display(psi.draw('latex'))

# Visualizar QSphere
print("🧠 Visualización QSphere:")
plot_state_qsphere(psi)
# Out:
# 🧪 Vector de estado:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# 🧪 Notación ket:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2}}{2} |11\rangle$$
# 🧠 Visualización QSphere:

# %% [markdown]
# ---
#
# ## 🧪 Explicación paso a paso del circuito
#
# 1. Aplicamos una compuerta **Hadamard al qubit 0**: esto genera una superposición del tipo
#
# $$
# \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)
# $$
#
# Lo que significa que el sistema queda en:
#
# $$
# \frac{1}{\sqrt{2}}(|00\rangle + |10\rangle)
# $$
#
# 2. Aplicamos una compuerta **CNOT**, con qubit 0 como control y qubit 1 como objetivo. Esto transforma el estado a:
#
# $$
# \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)
# $$
#
# Ya que la compuerta CNOT cambia el qubit objetivo **solo si** el qubit control está en
#
# $$
# |1\rangle
# $$
#
# 3. Aplicamos una compuerta **Z al qubit 0**, que invierte el signo de las componentes donde el qubit 0 está en el estado
#
# $$
# |1\rangle
# $$
#
# En este caso, afecta el término
#
# $$
# |11\rangle
# $$
#
# y el estado final queda como:
#
# $$
# |\Phi^-\rangle = \frac{1}{\sqrt{2}}(|00\rangle - |11\rangle)
# $$
#
# ---
#
# Este estado es un ejemplo clásico de **entrelazamiento con fase relativa negativa**, lo cual tiene efectos importantes en algoritmos cuánticos y protocolos como teleportación o criptografía cuántica.
#
# ---

# %% [markdown]
# ---
#
# ## 📊 8. Comparación visual de los Estados de Bell
#
# Los **estados de Bell** representan las 4 posibles formas de entrelazamiento máximo entre dos qubits. Cada uno es una superposición de dos estados base, con o sin diferencia de fase.
#
# | Estado de Bell | Expresión                                                        | Descripción detallada                                                                                       |
# |----------------|------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|
# | **Φ⁺**         | (1 / √2) · (  \|00⟩ + \|11⟩ )                                     | Ambos qubits están en el mismo estado. Fase positiva.                                                       |
# | **Φ⁻**         | (1 / √2) · (  \|00⟩ − \|11⟩ )                                     | Igual que Φ⁺, pero con una fase negativa. El signo menos afecta al término \|11⟩.                            |
# | **Ψ⁺**         | (1 / √2) · (  \|01⟩ + \|10⟩ )                                     | Qubits en estados opuestos. Hay simetría, con fase positiva.                                                |
# | **Ψ⁻**         | (1 / √2) · (  \|01⟩ − \|10⟩ )                                     | Qubits en estados opuestos, pero con fase negativa que invierte el término \|10⟩.                            |
#
# ---
#
# 📌 **Resumen**:
# - Los estados `Φ` son **correlacionados** (`|00⟩`, `|11⟩`), mientras que los `Ψ` son **anticorrelacionados** (`|01⟩`, `|10⟩`)
# - Los signos **+ o −** indican **fase relativa**: afectan la interferencia cuántica
# - Todos son **máximamente entrelazados** y **ortogonales entre sí**
#
# ---

# %%
#Codigo para visualizar los estados de bel (ilustrativo)
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere
import matplotlib.pyplot as plt
def mostrar_bell(nombre, circuito):
    estado = Statevector.from_instruction(circuito)
    
    print(f"🔎 Estado de Bell: {nombre}")
    display(circuito.draw('mpl'))
    display(plot_state_qsphere(estado))
# Φ⁺ = (|00⟩ + |11⟩) / √2
phi_plus = QuantumCircuit(2)
phi_plus.h(0)
phi_plus.cx(0, 1)

# Φ⁻ = (|00⟩ - |11⟩) / √2
phi_minus = QuantumCircuit(2)
phi_minus.h(0)
phi_minus.cx(0, 1)
phi_minus.z(0)

# Ψ⁺ = (|01⟩ + |10⟩) / √2
psi_plus = QuantumCircuit(2)
psi_plus.x(1)
psi_plus.h(0)
psi_plus.cx(0, 1)

# Ψ⁻ = (|01⟩ - |10⟩) / √2
psi_minus = QuantumCircuit(2)
psi_minus.x(1)
psi_minus.h(0)
psi_minus.cx(0, 1)
psi_minus.z(0)
mostrar_bell("Φ⁺ = (|00⟩ + |11⟩) / √2", phi_plus)
mostrar_bell("Φ⁻ = (|00⟩ - |11⟩) / √2", phi_minus)
mostrar_bell("Ψ⁺ = (|01⟩ + |10⟩) / √2", psi_plus)
mostrar_bell("Ψ⁻ = (|01⟩ - |10⟩) / √2", psi_minus)
# Out:
# 🔎 Estado de Bell: Φ⁺ = (|00⟩ + |11⟩) / √2
# 🔎 Estado de Bell: Φ⁻ = (|00⟩ - |11⟩) / √2
# 🔎 Estado de Bell: Ψ⁺ = (|01⟩ + |10⟩) / √2
# 🔎 Estado de Bell: Ψ⁻ = (|01⟩ - |10⟩) / √2

# %% [markdown]
# ---
#
# ## 📚 Referencias
#
# - [1] M. A. Nielsen y I. L. Chuang, *Quantum Computation and Quantum Information*, Cambridge University Press, 10th Anniversary Edition, 2010.
#
# - [2] R. S. S. Mano, M. Hidalgo, J. Venegas-Gomez, *Quantum Software Engineering: A Critical Review*, 2022.
#
# - [3] T. S. Humble et al., *Quantum Programming in Qiskit: An Introduction*, Oak Ridge National Laboratory, 2020.
#
# - [4] A. Hidary, *Quantum Computing: An Applied Approach*, Springer, 2021.
#
# - [5] Qiskit Documentation – IBM Quantum
#   https://qiskit.org/documentation/
#
# - [6] IBM Quantum Composer
#   https://quantum-computing.ibm.com/composer
#
# - [7] Qiskit Textbook: *Learn Quantum Computation using Qiskit*
#   https://qiskit.org/textbook
#
# - [8] OpenQuantum – *Quantum State Visualization Guide*
#   https://openquantum.dev
#
# ---
